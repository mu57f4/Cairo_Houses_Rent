# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data = pd.read_csv('dataset\houses.csv')
data.head()
# Out:
#                                          Description       Type   Price
# 0  بتهاوس مفروش للايجار - فورتي ويست بيفرلى هيلز ...  Penthouse  77,500  \
# 1  شقة للايجار بكمبوند  كايرو فيستفال سيتى القاهر...  Apartment  60,000
# 2  التفاصيل: شقة كورنر للإيجار في هايد بارك | الق...  Apartment  30,000
# 3  للأيجار مفروش شقه حجره وصاله مساحه ٦٠ م بقريه ...  Apartment   5,000
# 4  شقه 131 متر للإيجار تتكون من ثلاث غرف وحمامين ...  Apartment  15,000
#
#   Price Type          Video Area (m²) Bedrooms  Bathrooms Level Furnished
# 0      Price  Not Available       300        2          3     4       Yes  \
# 1      Price  Not Available       200        3          3   NaN       Yes
# 2      Price  Not Available       230        3          2     3       NaN
# 3      Price  Not Available        60        1          1     2       Yes
# 4      Price  Not Available       131        3          2     5       NaN
#
#    ... Landline Security Central A/C & heating Covered Parking Pets Allowed
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9612 entries, 0 to 9611
# Data columns (total 29 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   Description                  9612 non-null   object
#  1   Type                         9612 non-null   object
#  2   Price                        9612 non-null   object
#  3   Price Type                   9612 non-null   object
#  4   Video                        9612 non-null   object
#  5   Area (m²)                    9612 non-null   object
#  6   Bedrooms                     9612 non-null   object
#  7   Bathrooms                    9612 non-null   int64
#  8   Level                        9095 non-null   object
#  9   Furnished                    8630 non-null   object
#  10  Virtual Tour                 9612 non-null   object
#  11  Area                         9579 non-null   object
#  12  City                         9579 non-null   object
# ...
